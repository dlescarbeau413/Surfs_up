# %%
# Dependencies
import numpy as np
import pandas as pd

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func,inspect

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# ## D1: Determine the Summary Statistics for June

# %%
engine.execute('SELECT* FROM Measurement').fetchall()
# Out:
# [(1, 'USC00519397', '2010-01-01', 0.08, 65.0),
#  (2, 'USC00519397', '2010-01-02', 0.0, 63.0),
#  (3, 'USC00519397', '2010-01-03', 0.0, 74.0),
#  (4, 'USC00519397', '2010-01-04', 0.0, 76.0),
#  (5, 'USC00519397', '2010-01-06', None, 73.0),
#  (6, 'USC00519397', '2010-01-07', 0.06, 70.0),
#  (7, 'USC00519397', '2010-01-08', 0.0, 64.0),
#  (8, 'USC00519397', '2010-01-09', 0.0, 68.0),
#  (9, 'USC00519397', '2010-01-10', 0.0, 73.0),
#  (10, 'USC00519397', '2010-01-11', 0.01, 64.0),
#  (11, 'USC00519397', '2010-01-12', 0.0, 61.0),
#  (12, 'USC00519397', '2010-01-14', 0.0, 66.0),
#  (13, 'USC00519397', '2010-01-15', 0.0, 65.0),
#  (14, 'USC00519397', '2010-01-16', 0.0, 68.0),
#  (15, 'USC00519397', '2010-01-17', 0.0, 64.0),
#  (16, 'USC00519397', '2010-01-18', 0.0, 72.0),
#  (17, 'USC00519397', '2010-01-19', 0.0, 66.0),
#  (18, 'USC00519397', '2010-01-20', 0.0, 66.0),
#  (19, 'USC00519397', '2010-01-21', 0.0, 69.0),
#  (20, 'USC00519397', '2010-01-22', 0.0, 67.0),
# ...

# %%
inspector= inspect (engine)
inspector.get_table_names()
# Out:
# ['measurement', 'station']

# %%
columns= inspector.get_columns('measurement')
for c in columns:
    print(c['name'], c["type"])
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %%
# 1. Import the sqlalchemy extract function.
from sqlalchemy import extract

# 2. Write a query that filters the Measurement table to retrieve the temperatures for the month of June. 
results = session.query(Measurement.date,Measurement.tobs).filter(extract('month', Measurement.date) == 6).all()

# %%
#  3. Convert the June temperatures to a list.
print(results)
# Out:
# [('2010-06-01', 78.0), ('2010-06-02', 76.0), ('2010-06-03', 78.0), ('2010-06-04', 76.0), ('2010-06-05', 77.0), ('2010-06-06', 78.0), ('2010-06-07', 77.0), ('2010-06-08', 78.0), ('2010-06-09', 78.0), ('2010-06-10', 79.0), ('2010-06-11', 78.0), ('2010-06-12', 78.0), ('2010-06-13', 78.0), ('2010-06-14', 77.0), ('2010-06-15', 78.0), ('2010-06-16', 78.0), ('2010-06-17', 77.0), ('2010-06-18', 77.0), ('2010-06-19', 82.0), ('2010-06-20', 78.0), ('2010-06-21', 78.0), ('2010-06-22', 78.0), ('2010-06-23', 78.0), ('2010-06-24', 78.0), ('2010-06-25', 77.0), ('2010-06-26', 76.0), ('2010-06-27', 78.0), ('2010-06-28', 78.0), ('2010-06-29', 78.0), ('2010-06-30', 78.0), ('2011-06-01', 77.0), ('2011-06-02', 78.0), ('2011-06-03', 73.0), ('2011-06-04', 70.0), ('2011-06-05', 76.0), ('2011-06-06', 77.0), ('2011-06-07', 77.0), ('2011-06-08', 77.0), ('2011-06-09', 77.0), ('2011-06-10', 78.0), ('2011-06-11', 77.0), ('2011-06-12', 77.0), ('2011-06-13', 78.0), ('2011-06-14', 78.0), ('2011-06-15', 77.0), ('2011-
# ...

# %%
# 4. Create a DataFrame from the list of temperatures for the month of June. 
df = pd.DataFrame(results, columns=['date','June Temps'])
df.set_index(df['date'], inplace=True)

# %%
print(df.to_string(index=False))
# Out:
#       date  June Temps
# 2010-06-01        78.0
# 2010-06-02        76.0
# 2010-06-03        78.0
# 2010-06-04        76.0
# 2010-06-05        77.0
# 2010-06-06        78.0
# 2010-06-07        77.0
# 2010-06-08        78.0
# 2010-06-09        78.0
# 2010-06-10        79.0
# 2010-06-11        78.0
# 2010-06-12        78.0
# 2010-06-13        78.0
# 2010-06-14        77.0
# 2010-06-15        78.0
# 2010-06-16        78.0
# 2010-06-17        77.0
# 2010-06-18        77.0
# 2010-06-19        82.0
# 2010-06-20        78.0
# 2010-06-21        78.0
# 2010-06-22        78.0
# 2010-06-23        78.0
# 2010-06-24        78.0
# 2010-06-25        77.0
# 2010-06-26        76.0
# 2010-06-27        78.0
# 2010-06-28        78.0
# 2010-06-29        78.0
# 2010-06-30        78.0
# 2011-06-01        77.0
# 2011-06-02        78.0
# 2011-06-03        73.0
# 2011-06-04        70.0
# 2011-06-05        76.0
# 2011-06-06        77.0
# 2011-06-07        77.0
# 2011-06-08        77.0
# 2011-06-09        77.0
# ...

# %%
# 5. Calculate and print out the summary statistics for the June temperature DataFrame.
df.describe()
# Out:
#         June Temps
# count  1700.000000
# mean     74.944118
# std       3.257417
# min      64.000000
# 25%      73.000000
# 50%      75.000000
# 75%      77.000000
# max      85.000000

# %% [markdown]
# ## D2: Determine the Summary Statistics for December

# %%
# 6. Write a query that filters the Measurement table to retrieve the temperatures for the month of December.
results2 = session.query(Measurement.date,Measurement.tobs).filter(extract('month', Measurement.date) == 12).all()

# %%
# 7. Convert the December temperatures to a list.
print(results2)
# Out:
# [('2010-12-01', 76.0), ('2010-12-03', 74.0), ('2010-12-04', 74.0), ('2010-12-06', 64.0), ('2010-12-07', 64.0), ('2010-12-08', 67.0), ('2010-12-09', 77.0), ('2010-12-10', 66.0), ('2010-12-11', 69.0), ('2010-12-12', 68.0), ('2010-12-13', 68.0), ('2010-12-14', 71.0), ('2010-12-15', 74.0), ('2010-12-16', 67.0), ('2010-12-17', 66.0), ('2010-12-18', 69.0), ('2010-12-19', 71.0), ('2010-12-23', 70.0), ('2010-12-24', 70.0), ('2010-12-26', 74.0), ('2010-12-27', 74.0), ('2010-12-28', 71.0), ('2010-12-29', 75.0), ('2010-12-30', 75.0), ('2010-12-31', 72.0), ('2011-12-01', 69.0), ('2011-12-02', 68.0), ('2011-12-03', 73.0), ('2011-12-04', 74.0), ('2011-12-05', 73.0), ('2011-12-06', 73.0), ('2011-12-07', 73.0), ('2011-12-08', 73.0), ('2011-12-09', 71.0), ('2011-12-10', 73.0), ('2011-12-11', 73.0), ('2011-12-12', 77.0), ('2011-12-13', 72.0), ('2011-12-14', 71.0), ('2011-12-15', 73.0), ('2011-12-16', 70.0), ('2011-12-17', 73.0), ('2011-12-18', 69.0), ('2011-12-19', 74.0), ('2011-12-20', 72.0), ('2011-
# ...

# %%
# 8. Create a DataFrame from the list of temperatures for the month of December. 
df = pd.DataFrame(results2, columns=['date','December Temps'])
df.set_index(df['date'], inplace=True)

# %%
print(df.to_string(index=False))
# Out:
#       date  December Temps
# 2010-12-01            76.0
# 2010-12-03            74.0
# 2010-12-04            74.0
# 2010-12-06            64.0
# 2010-12-07            64.0
# 2010-12-08            67.0
# 2010-12-09            77.0
# 2010-12-10            66.0
# 2010-12-11            69.0
# 2010-12-12            68.0
# 2010-12-13            68.0
# 2010-12-14            71.0
# 2010-12-15            74.0
# 2010-12-16            67.0
# 2010-12-17            66.0
# 2010-12-18            69.0
# 2010-12-19            71.0
# 2010-12-23            70.0
# 2010-12-24            70.0
# 2010-12-26            74.0
# 2010-12-27            74.0
# 2010-12-28            71.0
# 2010-12-29            75.0
# 2010-12-30            75.0
# 2010-12-31            72.0
# 2011-12-01            69.0
# 2011-12-02            68.0
# 2011-12-03            73.0
# 2011-12-04            74.0
# 2011-12-05            73.0
# 2011-12-06            73.0
# 2011-12-07            73.0
# 2011-12-08            73.0
# ...

# %%
# 9. Calculate and print out the summary statistics for the Decemeber temperature DataFrame.
df.describe()
# Out:
#        December Temps
# count     1517.000000
# mean        71.041529
# std          3.745920
# min         56.000000
# 25%         69.000000
# 50%         71.000000
# 75%         74.000000
# max         83.000000

# %% [markdown]
# # D3: Extended Analysis for other months.Extra queries

# %%
results = session.query(Measurement.date,Measurement.tobs).filter(extract('month', Measurement.date) == 7).all()

# %%
print(results)
# Out:
# [('2010-07-01', 75.0), ('2010-07-02', 77.0), ('2010-07-03', 77.0), ('2010-07-04', 78.0), ('2010-07-05', 78.0), ('2010-07-06', 76.0), ('2010-07-07', 74.0), ('2010-07-08', 76.0), ('2010-07-09', 74.0), ('2010-07-10', 76.0), ('2010-07-11', 78.0), ('2010-07-12', 77.0), ('2010-07-13', 80.0), ('2010-07-16', 78.0), ('2010-07-17', 76.0), ('2010-07-18', 77.0), ('2010-07-19', 77.0), ('2010-07-21', 80.0), ('2010-07-22', 78.0), ('2010-07-24', 80.0), ('2010-07-25', 79.0), ('2010-07-26', 78.0), ('2010-07-27', 79.0), ('2010-07-28', 78.0), ('2010-07-29', 79.0), ('2010-07-30', 78.0), ('2010-07-31', 77.0), ('2011-07-01', 77.0), ('2011-07-02', 78.0), ('2011-07-03', 78.0), ('2011-07-04', 78.0), ('2011-07-05', 78.0), ('2011-07-06', 76.0), ('2011-07-07', 76.0), ('2011-07-08', 77.0), ('2011-07-09', 77.0), ('2011-07-10', 77.0), ('2011-07-11', 78.0), ('2011-07-12', 77.0), ('2011-07-13', 73.0), ('2011-07-14', 77.0), ('2011-07-15', 79.0), ('2011-07-16', 78.0), ('2011-07-17', 77.0), ('2011-07-18', 78.0), ('2011-
# ...

# %%
df = pd.DataFrame(results, columns=['date','July Temps'])
df.set_index(df['date'], inplace=True)

# %%
print(df.to_string(index=False))
# Out:
#       date  July Temps
# 2010-07-01        75.0
# 2010-07-02        77.0
# 2010-07-03        77.0
# 2010-07-04        78.0
# 2010-07-05        78.0
# 2010-07-06        76.0
# 2010-07-07        74.0
# 2010-07-08        76.0
# 2010-07-09        74.0
# 2010-07-10        76.0
# 2010-07-11        78.0
# 2010-07-12        77.0
# 2010-07-13        80.0
# 2010-07-16        78.0
# 2010-07-17        76.0
# 2010-07-18        77.0
# 2010-07-19        77.0
# 2010-07-21        80.0
# 2010-07-22        78.0
# 2010-07-24        80.0
# 2010-07-25        79.0
# 2010-07-26        78.0
# 2010-07-27        79.0
# 2010-07-28        78.0
# 2010-07-29        79.0
# 2010-07-30        78.0
# 2010-07-31        77.0
# 2011-07-01        77.0
# 2011-07-02        78.0
# 2011-07-03        78.0
# 2011-07-04        78.0
# 2011-07-05        78.0
# 2011-07-06        76.0
# 2011-07-07        76.0
# 2011-07-08        77.0
# 2011-07-09        77.0
# 2011-07-10        77.0
# 2011-07-11        78.0
# 2011-07-12        77.0
# ...

# %%
#Temps summary data for July
df.describe()
# Out:
#         July Temps
# count  1711.000000
# mean     76.082408
# std       3.356532
# min      61.000000
# 25%      74.000000
# 50%      76.000000
# 75%      78.000000
# max      87.000000

# %%
results = session.query(Measurement.date,Measurement.tobs).filter(extract('month', Measurement.date) == 11).all()

# %%
print(results)
# Out:
# [('2010-11-01', 75.0), ('2010-11-02', 73.0), ('2010-11-04', 73.0), ('2010-11-05', 77.0), ('2010-11-06', 76.0), ('2010-11-07', 77.0), ('2010-11-08', 76.0), ('2010-11-09', 73.0), ('2010-11-10', 73.0), ('2010-11-11', 77.0), ('2010-11-12', 77.0), ('2010-11-13', 76.0), ('2010-11-16', 73.0), ('2010-11-17', 73.0), ('2010-11-19', 72.0), ('2010-11-20', 69.0), ('2010-11-21', 69.0), ('2010-11-22', 68.0), ('2010-11-23', 69.0), ('2010-11-24', 76.0), ('2010-11-25', 76.0), ('2010-11-27', 75.0), ('2010-11-28', 74.0), ('2010-11-29', 69.0), ('2010-11-30', 74.0), ('2011-11-01', 71.0), ('2011-11-02', 77.0), ('2011-11-03', 77.0), ('2011-11-04', 75.0), ('2011-11-05', 76.0), ('2011-11-06', 77.0), ('2011-11-07', 78.0), ('2011-11-08', 76.0), ('2011-11-09', 76.0), ('2011-11-10', 76.0), ('2011-11-11', 74.0), ('2011-11-12', 75.0), ('2011-11-13', 76.0), ('2011-11-14', 73.0), ('2011-11-15', 71.0), ('2011-11-16', 75.0), ('2011-11-17', 76.0), ('2011-11-18', 78.0), ('2011-11-19', 76.0), ('2011-11-20', 75.0), ('2011-
# ...

# %%
df = pd.DataFrame(results, columns=['date','November Temps'])
df.set_index(df['date'], inplace=True)

# %%
print(df.to_string(index=False))
# Out:
#       date  November Temps
# 2010-11-01            75.0
# 2010-11-02            73.0
# 2010-11-04            73.0
# 2010-11-05            77.0
# 2010-11-06            76.0
# 2010-11-07            77.0
# 2010-11-08            76.0
# 2010-11-09            73.0
# 2010-11-10            73.0
# 2010-11-11            77.0
# 2010-11-12            77.0
# 2010-11-13            76.0
# 2010-11-16            73.0
# 2010-11-17            73.0
# 2010-11-19            72.0
# 2010-11-20            69.0
# 2010-11-21            69.0
# 2010-11-22            68.0
# 2010-11-23            69.0
# 2010-11-24            76.0
# 2010-11-25            76.0
# 2010-11-27            75.0
# 2010-11-28            74.0
# 2010-11-29            69.0
# 2010-11-30            74.0
# 2011-11-01            71.0
# 2011-11-02            77.0
# 2011-11-03            77.0
# 2011-11-04            75.0
# 2011-11-05            76.0
# 2011-11-06            77.0
# 2011-11-07            78.0
# 2011-11-08            76.0
# ...

# %%
df.describe()
# Out:
#        November Temps
# count     1488.000000
# mean        73.252688
# std          3.617282
# min         61.000000
# 25%         71.000000
# 50%         74.000000
# 75%         76.000000
# max         83.000000

# %%
results = session.query(Measurement.date,Measurement.tobs).filter(extract('month', Measurement.date) == 2).all()

# %%
print(results)
# Out:
# [('2010-02-01', 66.0), ('2010-02-03', 67.0), ('2010-02-04', 69.0), ('2010-02-05', 67.0), ('2010-02-06', 67.0), ('2010-02-07', 64.0), ('2010-02-08', 69.0), ('2010-02-09', 73.0), ('2010-02-11', 73.0), ('2010-02-12', 69.0), ('2010-02-13', 69.0), ('2010-02-14', 69.0), ('2010-02-15', 71.0), ('2010-02-16', 61.0), ('2010-02-17', 69.0), ('2010-02-19', 63.0), ('2010-02-20', 64.0), ('2010-02-21', 65.0), ('2010-02-22', 67.0), ('2010-02-23', 68.0), ('2010-02-24', 65.0), ('2010-02-25', 76.0), ('2010-02-26', 75.0), ('2010-02-28', 66.0), ('2011-02-01', 68.0), ('2011-02-02', 66.0), ('2011-02-03', 67.0), ('2011-02-04', 64.0), ('2011-02-05', 65.0), ('2011-02-06', 75.0), ('2011-02-07', 68.0), ('2011-02-08', 71.0), ('2011-02-09', 71.0), ('2011-02-10', 71.0), ('2011-02-12', 68.0), ('2011-02-13', 68.0), ('2011-02-14', 72.0), ('2011-02-15', 70.0), ('2011-02-16', 74.0), ('2011-02-19', 67.0), ('2011-02-20', 71.0), ('2011-02-21', 71.0), ('2011-02-22', 71.0), ('2011-02-23', 74.0), ('2011-02-24', 68.0), ('2011-
# ...

# %%
df = pd.DataFrame(results, columns=['date','February Temps'])
df.set_index(df['date'], inplace=True)

# %%
print(df.to_string(index=False))
# Out:
#       date  February Temps
# 2010-02-01            66.0
# 2010-02-03            67.0
# 2010-02-04            69.0
# 2010-02-05            67.0
# 2010-02-06            67.0
# 2010-02-07            64.0
# 2010-02-08            69.0
# 2010-02-09            73.0
# 2010-02-11            73.0
# 2010-02-12            69.0
# 2010-02-13            69.0
# 2010-02-14            69.0
# 2010-02-15            71.0
# 2010-02-16            61.0
# 2010-02-17            69.0
# 2010-02-19            63.0
# 2010-02-20            64.0
# 2010-02-21            65.0
# 2010-02-22            67.0
# 2010-02-23            68.0
# 2010-02-24            65.0
# 2010-02-25            76.0
# 2010-02-26            75.0
# 2010-02-28            66.0
# 2011-02-01            68.0
# 2011-02-02            66.0
# 2011-02-03            67.0
# 2011-02-04            64.0
# 2011-02-05            65.0
# 2011-02-06            75.0
# 2011-02-07            68.0
# 2011-02-08            71.0
# 2011-02-09            71.0
# ...

# %%
df.describe()
# Out:
#        February Temps
# count     1610.000000
# mean        69.442236
# std          3.981399
# min         56.000000
# 25%         67.000000
# 50%         70.000000
# 75%         72.000000
# max         83.000000

# %%
results = session.query(Measurement.date,Measurement.tobs).filter(extract('month', Measurement.date) == 1).all()

# %%
df = pd.DataFrame(results, columns=['date','Jan Temp '])
df.set_index(df['date'], inplace=True)

# %%
df.describe()
# Out:
#          Jan Temp
# count  1727.000000
# mean     68.726115
# std       4.367892
# min      54.000000
# 25%      66.000000
# 50%      69.000000
# 75%      72.000000
# max      81.000000

# %%
results = session.query(Measurement.date,Measurement.prcp).filter(extract('month', Measurement.date) == 6).all()

# %%
print(results)
# Out:
# [('2010-06-01', 0.0), ('2010-06-02', 0.01), ('2010-06-03', 0.0), ('2010-06-04', 0.0), ('2010-06-05', 0.0), ('2010-06-06', 0.0), ('2010-06-07', 0.0), ('2010-06-08', 0.0), ('2010-06-09', 0.0), ('2010-06-10', 0.0), ('2010-06-11', 0.0), ('2010-06-12', 0.0), ('2010-06-13', 0.0), ('2010-06-14', 0.0), ('2010-06-15', 0.0), ('2010-06-16', 0.0), ('2010-06-17', 0.0), ('2010-06-18', 0.0), ('2010-06-19', 0.0), ('2010-06-20', 0.0), ('2010-06-21', 0.0), ('2010-06-22', 0.0), ('2010-06-23', 0.0), ('2010-06-24', 0.0), ('2010-06-25', 0.0), ('2010-06-26', 0.02), ('2010-06-27', 0.0), ('2010-06-28', 0.0), ('2010-06-29', 0.0), ('2010-06-30', 0.0), ('2011-06-01', 0.07), ('2011-06-02', 0.0), ('2011-06-03', 0.56), ('2011-06-04', 0.89), ('2011-06-05', 0.0), ('2011-06-06', 0.0), ('2011-06-07', 0.0), ('2011-06-08', 0.03), ('2011-06-09', 0.01), ('2011-06-10', 0.0), ('2011-06-11', 0.0), ('2011-06-12', 0.0), ('2011-06-13', 0.0), ('2011-06-14', 0.0), ('2011-06-15', 0.0), ('2011-06-17', 0.0), ('2011-06-18', 0.0), ('2
# ...

# %%
df = pd.DataFrame(results, columns=['date','June Prcp'])
df.set_index(df['date'], inplace=True)

# %%
print(df.to_string(index=False))
# Out:
#       date  June Prcp
# 2010-06-01       0.00
# 2010-06-02       0.01
# 2010-06-03       0.00
# 2010-06-04       0.00
# 2010-06-05       0.00
# 2010-06-06       0.00
# 2010-06-07       0.00
# 2010-06-08       0.00
# 2010-06-09       0.00
# 2010-06-10       0.00
# 2010-06-11       0.00
# 2010-06-12       0.00
# 2010-06-13       0.00
# 2010-06-14       0.00
# 2010-06-15       0.00
# 2010-06-16       0.00
# 2010-06-17       0.00
# 2010-06-18       0.00
# 2010-06-19       0.00
# 2010-06-20       0.00
# 2010-06-21       0.00
# 2010-06-22       0.00
# 2010-06-23       0.00
# 2010-06-24       0.00
# 2010-06-25       0.00
# 2010-06-26       0.02
# 2010-06-27       0.00
# 2010-06-28       0.00
# 2010-06-29       0.00
# 2010-06-30       0.00
# 2011-06-01       0.07
# 2011-06-02       0.00
# 2011-06-03       0.56
# 2011-06-04       0.89
# 2011-06-05       0.00
# 2011-06-06       0.00
# 2011-06-07       0.00
# 2011-06-08       0.03
# 2011-06-09       0.01
# 2011-06-10       0.00
# ...

# %%
df.describe()
# Out:
#          June Prcp
# count  1574.000000
# mean      0.136360
# std       0.335731
# min       0.000000
# 25%       0.000000
# 50%       0.020000
# 75%       0.120000
# max       4.430000

# %%
results = session.query(Measurement.date,Measurement.prcp).filter(extract('month', Measurement.date) == 7).all()

# %%
df = pd.DataFrame(results, columns=['date','July Prcp'])
df.set_index(df['date'], inplace=True)

# %%
print(df.to_string(index=False))
# Out:
#       date  June Prcp
# 2010-07-01       0.01
# 2010-07-02       0.05
# 2010-07-03       0.09
# 2010-07-04       0.05
# 2010-07-05       0.06
# 2010-07-06       0.08
# 2010-07-07       0.08
# 2010-07-08       0.03
# 2010-07-09       0.06
# 2010-07-10       0.09
# 2010-07-11       0.00
# 2010-07-12       0.00
# 2010-07-13       0.00
# 2010-07-16        NaN
# 2010-07-17       0.02
# 2010-07-18       0.00
# 2010-07-19       0.04
# 2010-07-21       0.00
# 2010-07-22       0.00
# 2010-07-24       0.00
# 2010-07-25       0.00
# 2010-07-26       0.00
# 2010-07-27       0.00
# 2010-07-28       0.00
# 2010-07-29       0.00
# 2010-07-30       0.00
# 2010-07-31       0.02
# 2011-07-01       0.05
# 2011-07-02       0.02
# 2011-07-03       0.00
# 2011-07-04       0.00
# 2011-07-05       0.01
# 2011-07-06       0.01
# 2011-07-07       0.01
# 2011-07-08       0.00
# 2011-07-09       0.03
# 2011-07-10       0.02
# 2011-07-11       0.00
# 2011-07-12       0.00
# 2011-07-13       0.15
# ...

# %%
df.describe()
# Out:
#          July Prcp
# count  1569.000000
# mean      0.167922
# std       0.625977
# min       0.000000
# 25%       0.000000
# 50%       0.020000
# 75%       0.120000
# max      11.530000

# %%
results = session.query(Measurement.date,Measurement.prcp).filter(extract('month', Measurement.date) == 8).all()

# %%
df = pd.DataFrame(results, columns=['date','Aug Prcp'])
df.set_index(df['date'], inplace=True)

# %%
print(df.to_string(index=False))
# Out:
#       date  Aug Prcp
# 2010-08-01      0.04
# 2010-08-02      0.01
# 2010-08-03      0.02
# 2010-08-04      0.07
# 2010-08-05      0.08
# 2010-08-06      0.03
# 2010-08-07      0.00
# 2010-08-08      0.00
# 2010-08-09      0.00
# 2010-08-10      0.00
# 2010-08-11      0.00
# 2010-08-12      0.00
# 2010-08-13      0.00
# 2010-08-14      0.00
# 2010-08-15      0.01
# 2010-08-16      0.00
# 2010-08-17      0.05
# 2010-08-18      0.00
# 2010-08-19      0.00
# 2010-08-20      0.00
# 2010-08-21      0.00
# 2010-08-22      0.00
# 2010-08-23      0.01
# 2010-08-24      0.00
# 2010-08-25      0.04
# 2010-08-26      0.03
# 2010-08-27      0.00
# 2010-08-28      0.04
# 2010-08-29      0.00
# 2010-08-30      0.00
# 2010-08-31      0.00
# 2011-08-01      0.00
# 2011-08-02      0.00
# 2011-08-03      0.00
# 2011-08-04      0.02
# 2011-08-05      0.03
# 2011-08-06      0.01
# 2011-08-07      0.00
# 2011-08-08      0.00
# 2011-08-09      0.00
# 2011-08-11      0.00
# 2011-08-12      0.00
# ...

# %%
df.describe()
# Out:
#           Aug Prcp
# count  1492.000000
# mean      0.146662
# std       0.409549
# min       0.000000
# 25%       0.000000
# 50%       0.010000
# 75%       0.110000
# max       4.810000

# %%
results = session.query(Measurement.date,Measurement.prcp).filter(extract('month', Measurement.date) == 9).all()

# %%
df = pd.DataFrame(results, columns=['date','Sept Prcp'])
df.set_index(df['date'], inplace=True)

# %%
df.describe()
# Out:
#          Sept Prcp
# count  1379.000000
# mean      0.164249
# std       0.437928
# min       0.000000
# 25%       0.000000
# 50%       0.020000
# 75%       0.150000
# max       6.830000

# %%
results = session.query(Measurement.date,Measurement.prcp).filter(extract('month', Measurement.date) == 10).all()

# %%
df = pd.DataFrame(results, columns=['date','Oct Prcp'])
df.set_index(df['date'], inplace=True)

# %%
df.describe()
# Out:
#           Oct Prcp
# count  1445.000000
# mean      0.155606
# std       0.443684
# min       0.000000
# 25%       0.000000
# 50%       0.010000
# 75%       0.090000
# max       4.470000

# %%
results = session.query(Measurement.date,Measurement.prcp).filter(extract('month', Measurement.date) == 11).all()

# %%
df = pd.DataFrame(results, columns=['date','Nov Prcp'])
df.set_index(df['date'], inplace=True)

# %%
df.describe()
# Out:
#           Nov Prcp
# count  1368.000000
# mean      0.180380
# std       0.505714
# min       0.000000
# 25%       0.000000
# 50%       0.010000
# 75%       0.120000
# max       8.060000

# %%
results = session.query(Measurement.date,Measurement.prcp).filter(extract('month', Measurement.date) == 12).all()

# %%
df = pd.DataFrame(results, columns=['date','Dec Prcp'])
df.set_index(df['date'], inplace=True)

# %%
df.describe()
# Out:
#           Dec Prcp
# count  1405.000000
# mean      0.216819
# std       0.541399
# min       0.000000
# 25%       0.000000
# 50%       0.030000
# 75%       0.150000
# max       6.420000
